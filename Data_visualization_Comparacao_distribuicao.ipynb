# %% [markdown]
# <a href="https://colab.research.google.com/github/rvbittencourt07/Phyton_Data_science/blob/main/Data_visualization_Comparacao_distribuicao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definindo a paleta de cores
AZUL1, AZUL2, AZUL3, AZUL4, AZUL5 = '#03045e', '#0077b6', "#00b4d8", '#90e0ef', '#CDDBF3'
CINZA1, CINZA2, CINZA3, CINZA4, CINZA5 = '#212529', '#495057', '#adb5bd', '#dee2e6', '#f8f9fa'
VERMELHO1, LARANJA1, AMARELO1, VERDE1, VERDE2 = '#e76f51', '#f4a261',	'#e9c46a', '#4c956c', '#2a9d8f'

# %%
import pandas as pd

# %%
vendas = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/dataviz-graficos/master/dados/relatorio_vendas.csv")

vendas
# Out:
#      data_pedido  data_envio      modo_envio       nome_cliente  \
# 0     2018-11-09  2018-11-12       Econômica    Thiago Silveira
# 1     2018-11-09  2018-11-12       Econômica    Thiago Silveira
# 2     2018-06-13  2018-06-17       Econômica      Giovanna Lima
# 3     2017-10-12  2017-10-19  Entrega padrão  Ana Júlia da Cruz
# 4     2017-10-12  2017-10-19  Entrega padrão  Ana Júlia da Cruz
# ...          ...         ...             ...                ...
# 8935  2018-09-30  2018-10-04  Entrega padrão     Enrique Santos
# 8936  2019-11-18  2019-11-22  Entrega padrão    Heitor Silveira
# 8937  2019-11-18  2019-11-22  Entrega padrão    Heitor Silveira
# 8938  2016-01-22  2016-01-24       Econômica      Isabel Araújo
# 8939  2019-05-05  2019-05-10       Econômica   Esther Rodrigues
#
#      segmento_cliente          cidade               estado    regiao  \
# 0                 B2C  Ribeirão Preto            São Paulo   Sudeste
# 1                 B2C  Ribeirão Preto            São Paulo   Sudeste
# 2                 B2B  Rio de Janeiro       Rio de Janeiro   Sudeste
# 3                 B2C   Foz do Iguaçu               Paraná       Sul
# 4                 B2C   Foz do Iguaçu               Paraná       Sul
# ...               ...             ...                  ...       ...
# 8935              B2C  Rio de Janeiro       Rio de Janeiro   Sudeste
# 8936              B2B          Jequié                Bahia  Nordeste
# 8937              B2B          Jequié                Bahia  Nordeste
# 8938              B2C     João Pessoa              Paraíba  Nordeste
# 8939              B2C         Mossoró  Rio Grande do Norte  Nordeste
#
#                  departamento               tipo_produto  preco_base  \
# 0     Materiais de construção               encanamentos      409.70
# 1     Materiais de construção                ferramentas      705.10
# 2     Jardinagem e paisagismo                   sementes       19.02
# 3     Materiais de construção  materiais de revestimento      781.38
# 4     Jardinagem e paisagismo                      vasos       35.88
# ...                       ...                        ...         ...
# 8935               Automotivo    ferramentas automotivas       97.34
# 8936               Automotivo    ferramentas automotivas      223.01
# 8937               Automotivo                      pneus      121.23
# 8938  Materiais de construção                 iluminação       26.29
# 8939  Jardinagem e paisagismo     mobiliário de exterior      351.36
#
#       preco_unit_sem_desc  desconto  preco_unit_venda  quantidade   vendas  \
# 0                  445.33     0.000            445.33           2   890.66
# 1                  829.53     0.000            829.53           3  2488.59
# 2                   24.86     0.000             24.86           2    49.72
# 3                  840.19     0.225            651.15           5  3255.75
# 4                   42.24     0.100             38.02           2    76.04
# ...                   ...       ...               ...         ...      ...
# 8935               123.22     0.000            123.22           1   123.22
# 8936               271.97     0.000            271.97           1   271.97
# 8937               140.15     0.000            140.15           5   700.75
# 8938                31.79     0.100             28.61           3    85.83
# 8939               413.37     0.000            413.37           2   826.74
#
#        lucro
# 0      71.26
# 1     373.29
# 2      11.68
# 3    -651.15
# 4       4.28
# ...      ...
# 8935   25.88
# 8936   48.96
# 8937   94.60
# 8938    6.96
# 8939  124.02
#
# [8940 rows x 17 columns]

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_pedido          8940 non-null   object
#  1   data_envio           8940 non-null   object
#  2   modo_envio           8940 non-null   object
#  3   nome_cliente         8940 non-null   object
#  4   segmento_cliente     8940 non-null   object
#  5   cidade               8940 non-null   object
#  6   estado               8940 non-null   object
#  7   regiao               8940 non-null   object
#  8   departamento         8940 non-null   object
#  9   tipo_produto         8940 non-null   object
#  10  preco_base           8940 non-null   float64
#  11  preco_unit_sem_desc  8940 non-null   float64
#  12  desconto             8940 non-null   float64
#  13  preco_unit_venda     8940 non-null   float64
#  14  quantidade           8940 non-null   int64
#  15  vendas               8940 non-null   float64
#  16  lucro                8940 non-null   float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
vendas["data_pedido"] = pd.to_datetime(vendas["data_pedido"],format="%Y-%m-%d")
vendas["data_envio"] = pd.to_datetime(vendas["data_envio"],format="%Y-%m-%d")

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_pedido          8940 non-null   datetime64[ns]
#  1   data_envio           8940 non-null   datetime64[ns]
#  2   modo_envio           8940 non-null   object
#  3   nome_cliente         8940 non-null   object
#  4   segmento_cliente     8940 non-null   object
#  5   cidade               8940 non-null   object
#  6   estado               8940 non-null   object
#  7   regiao               8940 non-null   object
#  8   departamento         8940 non-null   object
#  9   tipo_produto         8940 non-null   object
#  10  preco_base           8940 non-null   float64
#  11  preco_unit_sem_desc  8940 non-null   float64
#  12  desconto             8940 non-null   float64
#  13  preco_unit_venda     8940 non-null   float64
#  14  quantidade           8940 non-null   int64
#  15  vendas               8940 non-null   float64
#  16  lucro                8940 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df_venda_ano = vendas.copy()
df_venda_ano = df_venda_ano[['data_pedido','vendas']]
df_venda_ano['ano'] = df_venda_ano['data_pedido'].dt.year
df_venda_ano.drop(labels='data_pedido',axis=1,inplace=True)
df_venda_ano = df_venda_ano.set_index('ano')
df_venda_ano
# Out:
#        vendas
# ano
# 2018   890.66
# 2018  2488.59
# 2018    49.72
# 2017  3255.75
# 2017    76.04
# ...       ...
# 2018   123.22
# 2019   271.97
# 2019   700.75
# 2016    85.83
# 2019   826.74
#
# [8940 rows x 1 columns]

# %%
df_venda_ano =df_venda_ano.groupby('ano').sum('Vendas')
df_venda_ano
# Out:
#           vendas
# ano
# 2016  1402652.33
# 2017  1489179.52
# 2018  1884161.41
# 2019  2305006.29

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def grafico_vendas(cores: list=[AZUL2]):
  fig, ax = plt.subplots(figsize=(10,4))
  sns.set_theme(style='white')
  ax = sns.barplot(data=df_venda_ano,x=df_venda_ano.index,y='vendas',palette= cores)
  ax.set_title('Vendas das lojas de departamento de\n2016 a 2019',loc='left',fontsize=18,color=CINZA1)
  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.xaxis.set_tick_params(labelsize=14,labelcolor=CINZA2)
  ax.set_yticklabels([])

  for i, valor in enumerate(df_venda_ano['vendas']):
    qtd = f'R$ {valor:,.0f}'.replace(',','.')
    offset= 1e5
    ax.text(i, valor + offset, qtd, color = CINZA2, fontsize=12, va='center', ha='center')

  sns.despine(left=True,bottom=True)

  return ax

ax = grafico_vendas()
# Out:
# /tmp/ipython-input-677423006.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df_venda_ano,x=df_venda_ano.index,y='vendas',palette= cores)
# /tmp/ipython-input-677423006.py:4: UserWarning:
# The palette list has fewer values (1) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(data=df_venda_ano,x=df_venda_ano.index,y='vendas',palette= cores)

# %%
cores = []
for ano in df_venda_ano.index:
  if df_venda_ano.loc[ano,'vendas'] == df_venda_ano.vendas.max():
    cores.append(AZUL2)
  else:
    cores.append(AZUL5)

ax = grafico_vendas(cores)

# Anotando uma conclusão no gráfico
ax.text(3.5, 1.5e6,
         'Em $\\bf{2019}$, as vendas\n'
         'nas lojas subiram\n'
         'aproximadamente $\\bf{22,3}$%\n'
         'em relação ao ano de 2018.',
         fontsize=14, linespacing=1.45, color=AZUL2)

fig = ax.get_figure()
# Out:
# /tmp/ipython-input-677423006.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df_venda_ano,x=df_venda_ano.index,y='vendas',palette= cores)

# %%
top_lucro = vendas.copy()
top_lucro = top_lucro[['tipo_produto','lucro']]
top_lucro
# Out:
#                    tipo_produto   lucro
# 0                  encanamentos   71.26
# 1                   ferramentas  373.29
# 2                      sementes   11.68
# 3     materiais de revestimento -651.15
# 4                         vasos    4.28
# ...                         ...     ...
# 8935    ferramentas automotivas   25.88
# 8936    ferramentas automotivas   48.96
# 8937                      pneus   94.60
# 8938                 iluminação    6.96
# 8939     mobiliário de exterior  124.02
#
# [8940 rows x 2 columns]

# %%
top_lucro = top_lucro.groupby('tipo_produto').agg('sum').sort_values('lucro',ascending=False)
top_lucro
# Out:
#                               lucro
# tipo_produto
# peças de reposição         91148.67
# pneus                      67460.05
# ferramentas automotivas    63330.22
# pesticidas                 53343.89
# ferramentas de jardinagem  53202.88
# ferramentas                41020.34
# vasos                      33941.85
# mobiliário de exterior     26784.59
# iluminação                 20264.54
# fertilizantes              11254.88
# decoração de jardim         9939.43
# sementes                    8865.09
# equipamentos de limpeza     8724.39
# mudas                       1381.42
# materiais de paisagismo    -1912.37
# encanamentos               -5622.34
# materiais de revestimento -28869.01

# %%
top_7 = top_lucro[:7]
top_7
# Out:
#                               lucro
# tipo_produto
# peças de reposição         91148.67
# pneus                      67460.05
# ferramentas automotivas    63330.22
# pesticidas                 53343.89
# ferramentas de jardinagem  53202.88
# ferramentas                41020.34
# vasos                      33941.85

# %%
def grafico_top7():
  fig,ax = plt.subplots(figsize=(10,4))
  fig.subplots_adjust(right=0.7)
  sns.set_theme(style='white')

  cores = [AZUL2,AZUL2,AZUL2,VERDE1,CINZA3,VERDE1]
  ax = sns.barplot(data=top_7,x='lucro',y=top_7.index,palette=cores)

  # Personalizando o gráfico
  ax.set_title('Top 7 produtos com maior lucro no catálogo (2016-2019)\n', fontsize=18, color=CINZA1, loc='left')
  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.set_xticklabels([])
  ax.yaxis.set_tick_params(labelsize=10, labelcolor = CINZA2)
  sns.despine(left = True, bottom = True)

  for i, valor in enumerate(top_7['lucro']):
    qtd = f'R$ {valor:,.0f}'.replace(',','.')
    offset= 1e3
    ax.text(valor - offset, i, qtd, color = CINZA5, fontsize=10, fontweight='bold', va='center', ha='right')


  return ax


ax = grafico_top7()
# Out:
# /tmp/ipython-input-366121363.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_7,x='lucro',y=top_7.index,palette=cores)
# /tmp/ipython-input-366121363.py:7: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(data=top_7,x='lucro',y=top_7.index,palette=cores)

# %%
df_vendas_reg = vendas.copy()

# %%
df_vendas_reg = df_vendas_reg[['data_pedido','regiao','vendas']]

# %%
df_vendas_reg['ano'] = df_vendas_reg['data_pedido'].dt.year
df_vendas_reg.drop(labels='data_pedido',axis=1,inplace=True)
df_vendas_reg
# Out:
#         regiao   vendas   ano
# 0      Sudeste   890.66  2018
# 1      Sudeste  2488.59  2018
# 2      Sudeste    49.72  2018
# 3          Sul  3255.75  2017
# 4          Sul    76.04  2017
# ...        ...      ...   ...
# 8935   Sudeste   123.22  2018
# 8936  Nordeste   271.97  2019
# 8937  Nordeste   700.75  2019
# 8938  Nordeste    85.83  2016
# 8939  Nordeste   826.74  2019
#
# [8940 rows x 3 columns]

# %%
vendas_reg = pd.crosstab(index = df_vendas_reg.ano,columns=df_vendas_reg.regiao,
                         values=df_vendas_reg.vendas,aggfunc='sum')
vendas_reg = vendas_reg[['Sudeste','Nordeste','Centro-Oeste','Norte','Sul']]
vendas_reg
# Out:
# regiao     Sudeste   Nordeste  Centro-Oeste      Norte        Sul
# ano
# 2016     739602.18  378521.83     121653.63  101580.57   61294.12
# 2017     803005.61  320804.28     149215.00  124164.47   91990.16
# 2018    1033836.21  401365.77     208068.71  108710.09  132180.63
# 2019    1146764.08  600738.87     257781.18  170311.34  129410.82

# %%
def grafico_vendas_regiao():
 cores = [AZUL2,AZUL3,AZUL4,CINZA2,CINZA1]
 ax = vendas_reg.plot(kind='bar',figsize=(10,6),stacked=True, color = cores)
 ax.set_title('Vendas das lojas de departamentos por regiao e ano',loc='left',fontsize=18)
 ax.set_xlabel('')
 ax.set_ylabel('')
 ax.set_yticklabels([])
 ax.xaxis.set_tick_params(labelsize=14,labelcolor=CINZA2,rotation=0)
 ax.set_frame_on(False)
 ax.tick_params(axis="both", which="both", length=0)
 ax.text(3.35, 1.1e6, '87%', fontweight='bold', fontsize=20, color=AZUL1)
 ax.text(3.35, 5.5e5,
        'das vendas nas lojas\n'
        'estão concentradas nas regiões\n'
        '$\\bf{Sudeste}$, $\\bf{Nordeste}$ e\n'
        '$\\bf{Centro-Oeste}$ em 2019.',
        fontsize=14,
        linespacing=1.45,
        color=AZUL1)
 return ax

# %%
ax = grafico_vendas_regiao()
ax.legend(bbox_to_anchor=(1,1), reverse = True, title = "Região", title_fontsize = 12, fontsize = 12)

for container in ax.containers:
    labels = [f'R$ {valor.get_height():,.0f}k'.replace(',','.') for valor in container]
    ax.bar_label(container,label_type='center',labels= labels,size=10,color=CINZA5,fontweight='bold')

ax.axvline(x = 3.3,ymin=0,ymax=0.83,color=AZUL1,linewidth=1.2)

# %%
df_envio = vendas.copy()
df_envio = df_envio[['modo_envio','segmento_cliente']]
df_envio_seg = pd.crosstab(index=df_envio.modo_envio,columns=df_envio.segmento_cliente).sort_values('B2B')
df_envio_seg
# Out:
# segmento_cliente   B2B   B2C
# modo_envio
# 24 horas           207   288
# Envio rápido       676   673
# Econômica          829   906
# Entrega padrão    2552  2809

# %%
df_envio_normalizado = pd.crosstab(index=df_envio.modo_envio,columns=df_envio.segmento_cliente,normalize='index')
df_envio_normalizado
# Out:
# segmento_cliente       B2B       B2C
# modo_envio
# 24 horas          0.418182  0.581818
# Econômica         0.477810  0.522190
# Entrega padrão    0.476031  0.523969
# Envio rápido      0.501112  0.498888

# %%
from matplotlib import transforms

def texto_colorido(x, y, texto, cores, esp=20, ax=None, **kw):
    cores = list(reversed(cores))
    t = ax.transData
    canvas = ax.figure.canvas

    for i, linha in enumerate(reversed(texto.split('\n'))):
        frases = linha.split('||')
        for s, cor in zip(frases, cores[i]):
            texto = ax.text(x, y, s, color=cor, transform=t, **kw)
            texto.draw(canvas.get_renderer())
            ex = texto.get_window_extent()
            t = transforms.offset_copy(texto._transform, x=ex.width,
                                       units='dots')

        t = transforms.offset_copy(ax.transData, x=0, y=(i + 1) * esp, units='dots')

# %%
fig,axs = plt.subplots(1,2,figsize = (15,6), sharey = True)

cores = [AZUL2,AZUL5]

axs[0].barh(df_envio_seg.index,df_envio_seg['B2B'],color = cores[0])
axs[0].barh(df_envio_seg.index,df_envio_seg['B2C'],left = df_envio_seg['B2B'],color = cores[1])
axs[0].set_title('Em valores absolutos')
axs[0].set_xlabel('')
axs[0].set_ylabel('')
axs[0].set_xticklabels([])
axs[0].yaxis.set_tick_params(labelsize=14,labelcolor=CINZA2)
axs[0].set_frame_on(False)
axs[0].tick_params(axis="both", which="both", length=0)
texto_colorido(0, 3.5, '$\\bf{B2B}$ | || $\\bf{B2C}$', cores = [cores], ax=axs[0], fontsize=12)

axs[1].barh(df_envio_normalizado.index, df_envio_normalizado["B2B"], color = cores[0])
axs[1].barh(df_envio_normalizado.index, df_envio_normalizado["B2C"], left = df_envio_normalizado["B2B"], color = cores[1])
axs[1].set_title('Em porcentagem', color = CINZA2)
axs[1].set_xlabel('')
axs[1].set_ylabel('')
axs[1].set_xticklabels([])
axs[1].set_frame_on(False)
axs[1].tick_params(axis='both', which='both', length=0)
texto_colorido(0, 3.5, '$\\bf{B2B}$ | || $\\bf{B2C}$', cores = [cores], ax=axs[1], fontsize=12)

fig.suptitle('Modo de envio mais utilizado pelos clientes B2B e B2C (2016 a 1019)',
             fontsize=18, color = CINZA1, ha = 'right', x = 0.8, y = 1.05)

for container in axs[0].containers:
    labels = [str(valor.get_width()) if valor.get_width() > 300 else '' for valor in container]
    axs[0].bar_label(container, label_type='center', labels=labels, size=10, color=CINZA5, fontweight='bold')

for container in axs[1].containers:
    labels = [f'{valor.get_width()*100:.1f}%' for valor in container]
    axs[1].bar_label(container, label_type='center', labels=labels, size=10, color=CINZA5, fontweight='bold')

# %%
df_sp = vendas.copy()
df_sp = df_sp.query('estado == "São Paulo"')[['data_pedido','vendas']]
df_sp
# Out:
#      data_pedido   vendas
# 0     2018-11-09   890.66
# 1     2018-11-09  2488.59
# 16    2016-11-12  2263.98
# 38    2019-09-11   500.36
# 42    2016-10-21   720.64
# ...          ...      ...
# 8915  2018-12-06   372.96
# 8919  2017-06-29   406.50
# 8920  2017-06-29   478.55
# 8929  2017-09-07   292.33
# 8930  2019-08-04    56.15
#
# [2285 rows x 2 columns]

# %%
df_sp.set_index('data_pedido',inplace=True)
df_sp = df_sp.resample("Q").agg('sum')
df_sp['vendas'] = round(df_sp['vendas'] / 1e3,2)
df_sp = df_sp.reset_index()
df_sp
# Out:
# /tmp/ipython-input-3616991980.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df_sp = df_sp.resample("Q").agg('sum')
#    data_pedido  vendas
# 0   2016-03-31   41.87
# 1   2016-06-30   43.79
# 2   2016-09-30  154.91
# 3   2016-12-31  144.82
# 4   2017-03-31   36.13
# 5   2017-06-30   76.86
# 6   2017-09-30  129.76
# 7   2017-12-31  197.94
# 8   2018-03-31   44.26
# 9   2018-06-30  109.64
# 10  2018-09-30  127.72
# 11  2018-12-31  269.44
# 12  2019-03-31   65.07
# 13  2019-06-30   85.11
# 14  2019-09-30  158.01
# 15  2019-12-31  325.57

# %%
def grafico_vendas_sp_tri():
  fig,ax = plt.subplots(figsize=(14,4))

  pontos_a_marcar = [True if mes == 12 else False for mes in df_sp['data_pedido'].dt.month]

  ax.plot(df_sp['data_pedido'],df_sp['vendas'],lw=3,color = AZUL5, marker = 'o',
          markersize = 10, markerfacecolor = AZUL2, markevery = pontos_a_marcar)


  ax.set_title('vendas por trimestre no estado de SP',fontsize = 18,color = CINZA1,loc = 'left')
  ax.text(0.3,0.95,'De 2016 a 2019 (em milhares de reais)',transform=ax.transAxes,color = CINZA2, fontsize = 12, ha='right', va='center')
  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.xaxis.set_tick_params(labelsize=14,labelcolor=CINZA2,rotation=0)
  ax.set_yticklabels([])
  ax.set_frame_on(False)
  plt.ylim(0,400)



  return ax

ax = grafico_vendas_sp_tri()

# %%
import matplotlib.dates as mdates

ax = grafico_vendas_sp_tri()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
x_labels = ['mar','jun','set','dez'] * 4
ax.set_xticks(df_sp.data_pedido)
ax.set_xticklabels(x_labels,ha='center')

texto = [16*" " + str(i) + 16*" " for i in range(2016,2020)]
ax.text(ax.get_xbound()[0] + 35, -80, f'|{texto[0]}|{texto[1]}|{texto[2]}|{texto[3]}|',fontsize = 14, color = CINZA2)

ano = 0
for i in range(3, len(df_sp["vendas"]), 4):
  ax.text(x = ax.get_xticks()[i], y = df_sp["vendas"][i] + 20, s = f"R$ {df_sp['vendas'][i]} mil", color = AZUL2, weight = "bold", fontsize = 10)
  ax.text(x = ax.get_xticks()[i] + 160, y = df_sp["vendas"][i] + 20, s = f"(4º Tri {2016 + ano})", color = CINZA2, weight = "bold", fontsize = 10)
  ano +=1

# %%
df_regiao = vendas.copy()
df_regiao = df_regiao[["regiao", "data_pedido", "vendas"]]


df_regiao = pd.crosstab(index = df_regiao.data_pedido, columns = df_regiao.regiao, values = df_regiao.vendas, aggfunc="sum")


df_regiao = df_regiao[["Sudeste", "Nordeste", "Centro-Oeste", "Norte", "Sul"]]
df_regiao
# Out:
# regiao        Sudeste  Nordeste  Centro-Oeste   Norte     Sul
# data_pedido
# 2016-01-04      55.92       NaN           NaN     NaN     NaN
# 2016-01-05     979.42       NaN           NaN     NaN     NaN
# 2016-01-06        NaN       NaN         66.42     NaN     NaN
# 2016-01-07   14940.66     43.44           NaN     NaN     NaN
# 2016-01-08     296.37       NaN           NaN     NaN     NaN
# ...               ...       ...           ...     ...     ...
# 2019-12-27        NaN   2552.32        152.15     NaN   10.64
# 2019-12-28     603.96       NaN           NaN     NaN     NaN
# 2019-12-29     677.65   4079.73           NaN  456.94     NaN
# 2019-12-30    8900.41    712.98           NaN     NaN     NaN
# 2019-12-31    1705.02       NaN           NaN     NaN  711.62
#
# [1209 rows x 5 columns]

# %%
df_regiao = df_regiao.resample('Q').agg('sum')
df_regiao = round(df_regiao / 1e3,2)
df_regiao
# Out:
# /tmp/ipython-input-1983614711.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df_regiao = df_regiao.resample('Q').agg('sum')
# regiao       Sudeste  Nordeste  Centro-Oeste  Norte    Sul
# data_pedido
# 2016-03-31     70.18     41.73         16.80   9.31   1.51
# 2016-06-30    122.72     87.41         30.83  24.68  10.62
# 2016-09-30    226.43    158.12         39.61  21.94  11.97
# 2016-12-31    320.27     91.27         34.41  45.65  37.19
# 2017-03-31    127.89     61.58          5.90  35.25   4.75
# 2017-06-30    161.54     54.93         16.96  13.35  21.23
# 2017-09-30    206.29     91.60         48.82  48.71  21.68
# 2017-12-31    307.28    112.69         77.54  26.86  44.34
# 2018-03-31    120.56     92.40         29.30  39.03   6.95
# 2018-06-30    180.87     93.71         77.91  31.35  46.78
# 2018-09-30    252.41     93.14         51.03  16.16  26.43
# 2018-12-31    480.00    122.12         49.83  22.17  52.02
# 2019-03-31    170.82    121.06         40.37  25.11  26.18
# 2019-06-30    178.62    101.92         30.02  57.40  34.39
# 2019-09-30    305.00    159.66         87.09  51.54  37.99
# 2019-12-31    492.32    218.10        100.30  36.26  30.85

# %%
import plotly.express as px

fig = px.line(df_regiao, x=df_regiao.index, y=df_regiao.columns, markers = True, labels={"regiao": "Região"},
              color_discrete_sequence=[AZUL2, VERMELHO1, AMARELO1 , VERDE1, CINZA3])

fig.update_layout(width=1300,height=600,font_family='DejaVu Sans', font_size=15,
                  font_color=CINZA2, title_font_color = CINZA1, title_font_size = 24,
                  title_text = 'faturamento da loja de departamento por trimestre' +
                                '<br><sup size=1 style="color:#555655">De 2016 a 2019<sup>',
                  xaxis_title='', yaxis_title='',plot_bgcolor=CINZA5)

fig.update_yaxes(tickprefix="R$ ", ticksuffix=" mil")

labels = ['T1<br>2016', 'T2<br>2016', 'T3<br>2016', 'T4<br>2016',
          'T1<br>2017', 'T2<br>2017', 'T3<br>2017', 'T4<br>2017',
          'T1<br>2018', 'T2<br>2018', 'T3<br>2018', 'T4<br>2018',
          'T1<br>2019', 'T2<br>2019', 'T3<br>2019', 'T4<br>2019']
fig.update_xaxes(ticktext = labels, tickvals=df_regiao.index)

fig.update_traces(mode='markers+lines',hovertemplate = "<b>Período:</b> %{x} <br> <b>Faturamento:</b> %{y}")
fig.update_layout(hovermode='x')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d847dd38-f928-4851-b6b8-5bbc774307d2" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d847dd38-f928-4851-b6b8-5bbc774307d2")) {                    Plotly.newPlot(                        "d847dd38-f928-4851-b6b8-5bbc774307d2",                        [{"hovertemplate":"\u003cb\u003ePeríodo:\u003c\u002fb\u003e %{x} \u003cbr\u003e \u003cb\u003eFaturamento:\u003c\u002fb\u003e %{y}","legendgroup":"Sudeste","line":{"color":"#0077b6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Sudeste","orientation":"v","showlegend":true,"x":["2016-03-31T00:00:00","2016-06-30T00:00:00","2016-09-30T00:00:00","2016-12-31T00:00:00","2017-03-31T00:00:00","2017-06-30T00:00:00","2017-09-30T00:00:00","2017-12-31T00:00:00","2018-03-31T00:00:00","2018-06-30T00:00:00","2018-09-30T00:00:00","2018-12-31T00:00:00","2019-03-31T00:00:00","2019-06-30T00:00:00","2019-09-30T00:00:00","2019-12-31T00:00:00"],"xaxis":"x","y":[70.18,122.72,226.43,320.27,127.89,161.54,206.29,307.28,120.56,180.87,252.41,480.0,170.82,178.62,305.0,492.32],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003ePeríodo:\u003c\u002fb\u003e %{x} \u003cbr\u003e \u003cb\u003eFaturamento:\u003c\u002fb\u003e %{y}","legendgroup":"Nordeste","line":{"color":"#e76f51","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Nordeste","orientation":"v","showlegend":true,"x":["2016-03-31T00:00:00","2016-06-30T00:00:00","2016-09-30T00:00:00","2016-12-31T00:00:00","2017-03-31T00:00:00","2017-06-30T00:00:00","2017-09-30T00:00:00","2017-12-31T00:00:00","2018-03-31T00:00:00","2018-06-30T00:00:00","2018-09-30T00:00:00","2018-12-31T00:00:00","2019-03-31T00:00:00","2019-06-30T00:00:00","2019-09-30T00:00:00","2019-12-31T00:00:00"],"xaxis":"x","y":[41.73,87.41,158.12,91.27,61.58,54.93,91.6,112.69,92.4,93.71,93.14,122.12,121.06,101.92,159.66,218.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003ePeríodo:\u003c\u002fb\u003e %{x} \u003cbr\u003e \u003cb\u003eFaturamento:\u003c\u002fb\u003e %{y}","legendgroup":"Centro-Oeste","line":{"color":"#e9c46a","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Centro-Oeste","orientation":"v","showlegend":true,"x":["2016-03-31T00:00:00","2016-06-30T00:00:00","2016-09-30T00:00:00","2016-12-31T00:00:00","2017-03-31T00:00:00","2017-06-30T00:00:00","2017-09-30T00:00:00","2017-12-31T00:00:00","2018-03-31T00:00:00","2018-06-30T00:00:00","2018-09-30T00:00:00","2018-12-31T00:00:00","2019-03-31T00:00:00","2019-06-30T00:00:00","2019-09-30T00:00:00","2019-12-31T00:00:00"],"xaxis":"x","y":[16.8,30.83,39.61,34.41,5.9,16.96,48.82,77.54,29.3,77.91,51.03,49.83,40.37,30.02,87.09,100.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003ePeríodo:\u003c\u002fb\u003e %{x} \u003cbr\u003e \u003cb\u003eFaturamento:\u003c\u002fb\u003e %{y}","legendgroup":"Norte","line":{"color":"#4c956c","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Norte","orientation":"v","showlegend":true,"x":["2016-03-31T00:00:00","2016-06-30T00:00:00","2016-09-30T00:00:00","2016-12-31T00:00:00","2017-03-31T00:00:00","2017-06-30T00:00:00","2017-09-30T00:00:00","2017-12-31T00:00:00","2018-03-31T00:00:00","2018-06-30T00:00:00","2018-09-30T00:00:00","2018-12-31T00:00:00","2019-03-31T00:00:00","2019-06-30T00:00:00","2019-09-30T00:00:00","2019-12-31T00:00:00"],"xaxis":"x","y":[9.31,24.68,21.94,45.65,35.25,13.35,48.71,26.86,39.03,31.35,16.16,22.17,25.11,57.4,51.54,36.26],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003ePeríodo:\u003c\u002fb\u003e %{x} \u003cbr\u003e \u003cb\u003eFaturamento:\u003c\u002fb\u003e %{y}","legendgroup":"Sul","line":{"color":"#adb5bd","dash":"solid"},"marker":{" ...
